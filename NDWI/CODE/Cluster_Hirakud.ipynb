# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/3rd-Year-Project/NDWI/CODE/Ban Sagar 2021-10-23 Features Set.csv")

# %%
# df["NDVI_nir"] = (df['Green'] - df['Nir'])/(df['Green'] + df['Nir'])
# df["NDVI_swir1"] = (df['Green'] - df['Swir1'])/(df['Green'] + df['Swir1'])
# df["NDVI_swir2"] = (df['Green'] - df['Swir2'])/(df['Green'] + df['Swir2'])

# %%
# df['Turbidity'] = (df['Green'] - df['Red'])/(df['Green'] + df['Red'])
# df['Water_ratio_index'] = (df['Green']+df['Red'])/(df['Swir1']+df['Nir'])

# %%
# df.to_csv("/content/drive/MyDrive/Satellite Images/Hirakud Lake 2021-05-16 Features Set.csv")

# %%
df
# Out:
#         Unnamed: 0  Pixel-X  Pixel-Y    Green  Red      Nir   Swir1   Swir2  \
# 0                0      184     2234  10146.0  0.0  10488.0  8649.0  8157.0
# 1                1      184     2235  10034.0  0.0   9582.0  8277.0  7902.0
# 2                2      184     2236   9939.0  0.0   9335.0  8206.0  7868.0
# 3                3      185     2235  10059.0  0.0   9860.0  8388.0  8016.0
# 4                4      185     2236   9921.0  0.0   9366.0  8208.0  7866.0
# ...            ...      ...      ...      ...  ...      ...     ...     ...
# 815257      815257     7233     4002   9427.0  0.0   9127.0  8477.0  8075.0
# 815258      815258     7233     4003   9319.0  0.0   9563.0  8531.0  8111.0
# 815259      815259     7233     4006   9257.0  0.0  10155.0  8940.0  8414.0
# 815260      815260     7234     4001   9237.0  0.0   9951.0  9090.0  8335.0
# 815261      815261     7234     4002   9240.0  0.0  10137.0  9136.0  8442.0
#
# ...

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing
import sklearn.cluster as cluster
import sklearn.metrics as metrics
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
scaler = MinMaxScaler()
scale = scaler.fit_transform(df[['Green','Red','Nir','Swir1','Swir2','NDVI_nir','NDVI_swir1','NDVI_swir2','NDVI_nir','Turbidity','Water_ratio_index']])
df_scale = pd.DataFrame(scale, columns = ['Green','Red','Nir','Swir1','Swir2','NDVI_nir','NDVI_swir1','NDVI_swir2','NDVI_nir','Turbidity','Water_ratio_index']);
df_scale.head(5)
# Out:
#       Green  Red       Nir     Swir1     Swir2  NDVI_nir  NDVI_swir1  \
# 0  0.346597  0.0  0.308919  0.251405  0.194250  0.473233    0.272752
# 1  0.329390  0.0  0.222403  0.194896  0.152834  0.564380    0.328614
# 2  0.314795  0.0  0.198816  0.184111  0.147312  0.583464    0.327090
# 3  0.333231  0.0  0.248950  0.211758  0.171350  0.534351    0.310218
# 4  0.312029  0.0  0.201776  0.184414  0.146987  0.577571    0.323599
#
#    NDVI_swir2  NDVI_nir  Turbidity  Water_ratio_index
# 0    0.470917  0.473233        1.0           0.092725
# 1    0.498579  0.564380        1.0           0.116957
# 2    0.491622  0.583464        1.0           0.120607
# 3    0.482741  0.534351        1.0           0.108841
# 4    0.489536  0.577571        1.0           0.119009

# %%
km=KMeans(n_clusters=2)
y_predicted = km.fit_predict(df_scale)
y_predicted
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
df_Res = pd.DataFrame(y_predicted)
df_Res[0]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 815257    1
# 815258    1
# 815259    1
# 815260    1
# 815261    1
# Name: 0, Length: 815262, dtype: int32

# %%
df['Cluster'] = df_Res[0]

# %%
df.to_csv("/content/drive/MyDrive/3rd-Year-Project/NDWI/CODE/Ban Sagar_Kmeans_Cluster_river.csv")
